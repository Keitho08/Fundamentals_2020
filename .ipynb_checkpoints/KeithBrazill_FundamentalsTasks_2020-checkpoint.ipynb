# %% [markdown]
# ***
# ## Computer Science and Data Analytics
# * ### Fundamentals of Data Analysis
# * ### Tasks 2020
# * ### By:  Keith Brazill - G00387845
#
# *This assignement is submitted as part of the requirements for partial fullfilment of a postgraduate diploma in Computer Science with Data Analytics at Galway Mayo Institute of Technology.*
# ![alt text](https://learnonline.gmit.ie/pluginfile.php/1/theme_adaptable/logo/1606983803/Transparent%20new.png "GMIT Logo")

# %% [markdown]
# <br>
#
# ***
# # 1. Introduction
#
# This notebook will carry out the four tasks assigned as part of the module Fundamentals of Data Analysis on the postgraduate diploma in Computer Science with Data Analytics at Galway Mayo Institute of Technology.
#
# This notebook consists of the following:
#
# 1. Introduction
# 2. Task 1 - Counts: A python function that takes a list as input and counts the frequency of each value.
# 3. Task 2 - Dicerolls: A python function that simulates rolling dice based on the parameters; number of dice and number of rolls.
# 4. Task 3 - Coin FLips: A numpy binomial function that simulates coin flipping.
# 5. Task 4 - Simpson Paradox: The simpson paradox is explained using the python numpy package
# 6. Conclusion
#
# For each of the tasks the brief is provided and then using a combination of code and markdown cells each task is completed and clearly explained throughout. References are provided following each section.

# %% [markdown]
# <br>
#
# ***
# # 2. Task 1 - Counts
# **Task Brief:**
#
# *Write a Python function called counts that takes a list as input and returns a dictionary of unique items in the list as keys and the number of times each item appears as values. So, the input ['A', 'A', 'B', 'C', 'A'] should have output {'A': 3, 'B': 1, 'C': 1}. Your code should not depend on any module from the standard library or otherwise. You should research the task first and include a description with references of your algorithm in the notebook.*
# ***

# %% [markdown]
# **Task Methodology**
#
# Following numerous hours researching examples of this code online and carrying out practice examples, the code has been refined to below which carries out the task above in a concise manner. Firstly a list is created (lst) and then parameter "n" is defined which prompts the user to input an integer for the number of values to be input into the list, which is important for the next step. We then create a function that for each value input starting from first (0) to last (user defined n) we append the value into our list (lst). Finally we create our dictionary (dict) which counts frequency of each item (x) for number of items (x) in the list. This is achieved using code below:

# %%
# First we are going to create a list
lst = [] 
  
# We then prompt the user to tell us how many elements are in this list
n = int(input("Enter number of items in list: ")) 
  
# We then tell python to let the user input the items in the list from 0 to total number input (n)
for i in range(0, n): 
    item = (input()) 
  
    lst.append(item) # adding the items to the list

dict((x, lst.count(x)) for x in lst) 

# Here we tell python using the dict comamand that for each item in the list (x)
# we want a count of the number of times the item (x) appears in the list
# Out:
# Enter number of items in list: 5
# A
# A
# B
# C
# A
# {'A': 3, 'B': 1, 'C': 1}

# %% [markdown]
# Running the above code with input values: 5, A, A, B, C, A, we get the required output: {'A': 3, 'B': 1, 'C': 1}. Whilst researching the task it was found that there is a python collections library available that could be used to simplify the task, however the brief here was to complete task without importing specialist libraries.

# %% [markdown]
# ***
# **Python Packages used for Task 1:**
# * Default Python packages installed while installing python using Anaconda, no specific packages imported for task.
# ***

# %% [markdown]
# **Task References**
#
# 1. Stack Overflow. 2020. Using A Dictionary To Count The Items In A List. [online] Available at: <https://stackoverflow.com/questions/3496518/using-a-dictionary-to-count-the-items-in-a-list> [Accessed 4 December 2020].
# 2. Stack Overflow. 2020. Using A Dictionary To Count The Items In A List. [online] Available at: <https://stackoverflow.com/questions/3496518/using-a-dictionary-to-count-the-items-in-a-list> [Accessed 4 December 2020].
# 3. GeeksforGeeks. 2020. Python | Get A List As Input From User - Geeksforgeeks. [online] Available at: <https://www.geeksforgeeks.org/python-get-a-list-as-input-from-user/> [Accessed 4 December 2020].
# 4. Stack Overflow. 2020. How Can I Count The Occurrences Of A List Item?. [online] Available at: <https://stackoverflow.com/questions/2600191/how-can-i-count-the-occurrences-of-a-list-item> [Accessed 4 December 2020].
# 5. Docs.python.org. 2020. 5. Data Structures — Python 3.9.1Rc1 Documentation. [online] Available at: <https://docs.python.org/3/tutorial/datastructures.html#dictionaries> [Accessed 4 December 2020].
# 6. Docs.python.org. 2020. Built-In Types — Python 3.9.1Rc1 Documentation. [online] Available at: <https://docs.python.org/3/library/stdtypes.html#typesmapping> [Accessed 4 December 2020].
# 7. Docs.python.org. 2020. Built-In Types — Python 3.9.1Rc1 Documentation. [online] Available at: <https://docs.python.org/3/library/stdtypes.html#typesmapping> [Accessed 4 December 2020].
# 8. Codegrepper.com. 2020. Return Occurences In List Python Code Example. [online] Available at: <https://www.codegrepper.com/code-examples/python/return+occurences+in+list+python> [Accessed 4 December 2020].
# ***

# %% [markdown]
# <br>
#
# # 3. Task 2 - Dicerolls
# **Task Brief:**
#
# *November 2nd, 2020: Write a Python function called dicerolls that simulates rolling dice. Your function should take two parameters: the number of dice k and the number of times to roll the dice n. The function should simulate randomly rolling k dice n times, keeping track of each total face value. It should then return a dictionary with the number of times each possible total face value occurred. So, calling the function as diceroll(k=2, n=1000) should return a dictionary like: {2:19,3:50,4:82,5:112,6:135,7:174,8:133,9:114,10:75,11:70,12:36}*
# ***

# %% [markdown]
# **Task Methodology**
#
# Following numerous hours researching examples of this code online and carrying out practice examples, the code has been refined to below which carries out the task above in a concise manner. We use the numpy package to generate random number for the dicerolls. We first define the diceroll function and parameters (k=number of dice, n= number of rolls, dice_sides=6). We then create a dictionary of the dicerolls which we call "counter". The dictionary is based on the number of rolls n and for each number of rolls we multiply the number of dice by the number of sides and then add 1. The reason we add one is for example:
#
# * if k=2, 2x6=12, in python 12 = 11, so if we add 1 (13) the 13th value will be 12 which will be the maximum roll.
#
# Next we can simulate rolling the dice:
#
# * for i in range n(the number of rolls)
# * we want a sum of (dice_sum) a random choice in the range of 1 (minimum dice roll) to dice_sides + 1 (7th position = value = 6), multiplied by k(number of dice).
# * We then use our counter variable on dice_sum which runs the simulation for a second time and returns both results to the dictionary.
#
# Finally using our created variables we are now ready to use the diceroll function based on input values k and n as can be seen in code below:

# %%
import random as rd # imports numpy random directly as rd

# k = Number of dice
# n = Number of rolls

# First lets create dicerolls function:
def diceroll(k, n, dice_sides=6): 
    # prepare dictionary with zero values for all possible results based on number of dice and rolls
    counter = {n : 0 for n in range(k, k*dice_sides + 1)}
# The dictionary is based on the number of rolls (n) and for each number of rolls
# we multiply the number of dice by the number of sides and then add 1.
# roll all the dice:
    for i in range(n):
        dice_sum = sum(rd.choices(range(1, dice_sides + 1), k = k)) #runs the dice_sum function
        # sum of (dice_sum) a random choice in the range of 1 (minimum dice roll) 
        # to dice_sides + 1 (7th position = value = 6), multiplied by k(number of dice).
        counter[dice_sum] += 1 # runs dice_sum again and adds both variables to each other
    return counter # returns results to diceroll function

diceroll(k=2, n=1000) # run the function and display output using parameters k and n.
# Out:
# {2: 22,
#  3: 46,
#  4: 75,
#  5: 108,
#  6: 143,
#  7: 172,
#  8: 124,
#  9: 121,
#  10: 94,
#  11: 63,
#  12: 32}

# %% [markdown]
# An example of the output which will change each time as no seed is applied is:
# {2: 21,
#  3: 50,
#  4: 96,
#  5: 122,
#  6: 135,
#  7: 161,
#  8: 132,
#  9: 105,
#  10: 84,
#  11: 69,
#  12: 25}. Numpy random choiceS distribution was used to generate a random sample from this array. The choices() method returns a list with the randomly selected element from the specified sequence and this can be a string, a range or a list etc., in this case we defined the range to make the choice from.
#
# The sequence can be a string, a range, a list, a tuple or any other kind of sequence.

# %% [markdown]
# ***
# **Python Packages used for Task 2:**
# * Numpy Random Package, specifically numpy.random.choices
# ***

# %% [markdown]
# **Task References**
#
# 1. W3schools.com. 2020. Python Random Choices() Method. [online] Available at: <https://www.w3schools.com/python/ref_random_choices.asp> [Accessed 4 December 2020].
# 2. Docs.scipy.org. 2020. Numpy.Random.Choice — Numpy V1.10 Manual. [online] Available at: <https://docs.scipy.org/doc//numpy-1.10.4/reference/generated/numpy.random.choice.html> [Accessed 4 December 2020].
# 3. Stack Overflow. 2020. Rolling Two Dice And Tabulating Outcomes. [online] Available at: <https://stackoverflow.com/questions/23598952/rolling-two-dice-and-tabulating-outcomes?rq=1> [Accessed 4 December 2020].
# 4. Stack Overflow. 2020. Rolling Two Dice And Returning Count. [online] Available at: <https://stackoverflow.com/questions/49881078/rolling-two-dice-and-returning-count?rq=1> [Accessed 4 December 2020].
# 5. PythonForBeginners.com. 2020. Python Game : Rolling The Dice - Pythonforbeginners.Com. [online] Available at: <https://www.pythonforbeginners.com/code-snippets-source-code/game-rolling-the-dice> [Accessed 4 December 2020].
# 6. Stack Overflow. 2020. Dice Rolling Simulator In Python. [online] Available at: <https://stackoverflow.com/questions/44008489/dice-rolling-simulator-in-python> [Accessed 4 December 2020].
# 7. Data Science Unlimited. 2020. Step By Step: Coding A Dice Roll Simulator In Python | Examples For Beginners. [online] Available at: <https://datascienceunlimited.tech/step-by-step-coding-a-dice-roll-simulator-in-python/> [Accessed 4 December 2020].
# 8. Medium. 2020. How To Simulate A Dice Roll And Guess The Result In Python. [online] Available at: <https://medium.com/an-amygdala/how-to-simulate-a-dice-roll-and-guess-the-result-in-python-9785079af6f3> [Accessed 4 December 2020].
# 9. Docs.scipy.org. 2020. Numpy.Random.Choice — Numpy V1.10 Manual. [online] Available at: <https://docs.scipy.org/doc//numpy-1.10.4/reference/generated/numpy.random.choice.html> [Accessed 4 December 2020].
# 10. Pynative.com. 2020. Python-Range-Function/. [online] Available at: <https://pynative.com/python-range-function/> [Accessed 4 December 2020].
# 11. GeeksforGeeks. 2020. Count Numbers In Range Such That Digits In It And It's Product With Q Are Unequal - Geeksforgeeks. [online] Available at: <https://www.geeksforgeeks.org/count-numbers-in-range-such-that-digits-in-it-and-its-product-with-q-are-unequal/> [Accessed 4 December 2020].

# %% [markdown]
# <br>
#
# # 4. Task 3 - Coin Flips
# **Task Brief:**
# *November 16th, 2020: The numpy.random.binomial function can be used to simulate flipping a coin with a 50/50 chance of heads or tails. Interestingly, if a coin is flipped many times then the number of heads is well approximated by a bell-shaped curve. For instance, if we flip a coin 100 times in a row the chance of getting 50 heads is relatively high, the chances of getting 0 or 100 heads is relatively low, and the chances of getting any other number of heads decreases as you move away from 50 in either direction towards 0 or 100. Write some python code that simulates flipping a coin 100 times. Then run this code 1,000 times, keeping track of the number of heads in each of the 1,000 simulations. Select an appropriate plot to depict the resulting list of 1,000 numbers, showing that it roughly follows a bell-shaped curve. You should explain your work in a Markdown cell above the code.*
# ***

# %% [markdown]
# **Task Methodology**
#
# Following numerous hours researching examples of this code online and carrying out practice examples, the code has been refined to below which carries out the task above in a concise manner. This task is also comparable to the programming and scripting assignment issued as part of the course this year and many of the learnings are taken from here and the relevant repository is referenced also. This demonstrates the versatility of the code and how it can be amended to suit each application. In the following sections we will explain the code for each coin flip simulation and give an analysis of each.

# %%
import numpy as np # numpy is imported as np
from numpy import random as rd # we will use the random function explained above with the binomial function
import matplotlib.pyplot as plt # import matplotlib as plt, seaborn is build on top of this
import seaborn as sns # imports seaborn library as sns used for displaying plots to user format
plt.style.use("ggplot") # A nicer style to use for plots
plt.rcParams["figure.figsize"] = (12,8) #sets the plots size, bigger than default notebook and better presented. 

np.random.seed(2) # sets the seed to 2 so we can re-generate same results each time, useful for analysis. 
flip = rd.binomial(n=1, p=0.5, size=100) 
# we define the flip function and input values for parameters above, n=1 as the number of outcomes is 2 (0 + 1), 
# p = 0.5 as probability is 50%, size is number of flips (100)
unique, counts = np.unique(flip, return_counts=True)
# numpy unique returns the sorted unique elements of an array
print(dict(zip(unique, counts)))
# dict(zip) converts two lists to a dictionary, for each value we combine the individual values with count and print out
# 0 = heads, 1 = tails

flipplot = sns.histplot(flip, kde=True, binwidth=0.5) 
# generates a histogram of results for <0.5 and >0.5. We want a kde to show the curve
# setting binwitdh to 0.5 allows a clear demarcation between results.
plt.setp(flipplot,xticks=[0.25,0.75])
# We want the x ticks in these positions as they are centred in the histograms, user preference
flipplot.set(xticklabels=["Heads", "Tails"]) # We label the 0 results as heads and 1 results as tails on the x-axis
plt.xlabel("Coinfaces (Heads or Tails)") # plots labels to x axis
plt.ylabel("Number of coin tosses") # plots labels to y axis

# kernel density estimate (kde) is required to demonstrate bell shaped curve, 
# we set binwidth to 0.5 to ensure the ranges in the histogram are correctly identified.
# i.e 0-0.5 = heads, 0.5-1.0 = Tails
# Out:
# {0: 56, 1: 44}
# Text(0, 0.5, 'Number of coin tosses')

# %% [markdown]
# We can see from our inital code ran above that when we run the simulation we get a bias towards heads(0) as out of 100 coin flips we get 56 heads with this particular seed. We can see the bell curve is formed with a bias towards heads.
# This type of bell curve is known an inverted bell curve and as defined by Wikepedia; *"In statistics, an inverted bell curve is a term used loosely or metaphorically to refer to a bimodal distribution that falls to a trough between two peaks, rather than (as in a standard bell curve) rising to a single peak and then falling off on both sides.*
# As we increase the number of samples(flips) we are more likely to get a flatter bell curve. Lets test in the following sections of code.

# %%
import numpy as np # numpy is imported as np
from numpy import random as rd # we will use the random function explained above with the binomial function
import matplotlib.pyplot as plt # import matplotlib as plt, seaborn is build on top of this
import seaborn as sns # imports seaborn library as sns used for displaying plots to user format
plt.style.use("ggplot") # A nicer style to use for plots
plt.rcParams["figure.figsize"] = (12,8) #sets the plots size, bigger than default notebook and better presented. 

np.random.seed(2) # sets the seed to 2 so we can re-generate same results each time, useful for analysis.

flip = rd.binomial(n=1, p=0.5, size=1000) # we define the flip function and input values for parameters above, p = 0.5 as probability is 50%
# we define the flip function and input values for parameters above, n=1 as the number of outcomes is 2 (0 + 1), 
# p = 0.5 as probability is 50%, size is number of flips (1000)
unique, counts = np.unique(flip, return_counts=True)
# numpy unique returns the sorted unique elements of an array
print(dict(zip(unique, counts)))
# dict(zip) converts two lists to a dictionary, for each value we combine the individual values with count and print out
# 0 = heads, 1 = tails

flipplot = sns.histplot(flip, kde=True, binwidth=0.5,) 
# generates a histogram of results for <0.5 and >0.5. We want a kde to show the curve
# setting binwitdh to 0.5 allows a clear demarcation between results.
plt.setp(flipplot,xticks=[0.25,0.75])
# We want the x ticks in these positions as they are centred in the histograms, user preference
flipplot.set(xticklabels=["Heads", "Tails"]) # We label the 0 results as heads and 1 results as tails on the x-axis
plt.xlabel("Coinfaces (Heads or Tails)")  # plots labels to x axis
plt.ylabel("Number of coin tosses") # plots labels to y axis

# kernel density estimate (kde) is required to demonstrate bell shaped curve, 
# we set binwidth to 0.5 to ensure the ranges in the histogram are correctly identified. 
# i.e 0-0.5 = heads, 0.5-1.0 = Tails
# Out:
# {0: 534, 1: 466}
# Text(0, 0.5, 'Number of coin tosses')

# %% [markdown]
# In the above graph we increased the number of flips from 100 to 1000. We now get a flatter bell curve with a slight bias towards heads for this particular seed. The number of heads in this instance was 534 out of 1000. Finally lets run the simulation one more time with 10000 flips.

# %%
import numpy as np # numpy is imported as np
from numpy import random as rd # we will use the random function explained above with the binomial function
import matplotlib.pyplot as plt # import matplotlib as plt, seaborn is build on top of this
import seaborn as sns # imports seaborn library as sns used for displaying plots to user format
plt.style.use("ggplot") # A nicer style to use for plots
plt.rcParams["figure.figsize"] = (12,8) #sets the plots size, bigger than default notebook and better presented. 

np.random.seed(6) # sets the seed to 6 as wanted to demonstrate this particular outcome

flip = rd.binomial(n=1, p=0.5, size=10000) 
# we define the flip function and input values for parameters above, n=1 as the number of outcomes is 2 (0 + 1), 
# p = 0.5 as probability is 50%, size is number of flips (10000)
unique, counts = np.unique(flip, return_counts=True)
# numpy unique returns the sorted unique elements of an array
print(dict(zip(unique, counts)))
# dict(zip) converts two lists to a dictionary, for each value we combine the individual values with count and print out
# 0 = heads, 1 = tails

flipplot = sns.histplot(flip, kde=True, binwidth=0.5,) 
# generates a histogram of results for <0.5 and >0.5. We want a kde to show the curve
# setting binwitdh to 0.5 allows a clear demarcation between results.
plt.setp(flipplot,xticks=[0.25,0.75])
# We want the x ticks in these positions as they are centred in the histograms, user preference
flipplot.set(xticklabels=["Heads", "Tails"]) # We label the 0 results as heads and 1 results as tails on the x-axis
plt.xlabel("Coinfaces (Heads or Tails)") # plots labels to x axis
plt.ylabel("Number of coin tosses") # plots labels to y axis

# kernel density estimate (kde) is required to demonstrate bell shaped curve, 
# we set binwidth to 0.5 to ensure the ranges in the histogram are correctly identified. 
# i.e 0-0.5 = heads, 0.5-1.0 = Tails
# Out:
# {0: 4916, 1: 5084}
# Text(0, 0.5, 'Number of coin tosses')

# %% [markdown]
# On the final iteration we got close to a rectangle in shape for 10000 coin flips there was little bias towards either heads or tails. This time we changed the seed to 6, as this particular simulation showed a bias towards tails, 5084 flips out of 10000 were tails and 4916 were heads. The bell curve is very flat and only a very slight bias towards tails in this iteration.
# The simulations above have demonstrated the significance of sample size when carrying out data analysis as the larger the sample size the greater the reflection of the probability and accuracy of the data analysis.

# %% [markdown]
# ***
# **Python Packages used for Task 3:**
# * Numpy Random Package, specifically random.seed, random.unique, random.binomial
# * Matplolib.pyplot
# * Seaborn
# ***

# %% [markdown]
# **References**
#
# 1. W3schools.com. 2020. Introduction To Random Numbers In Numpy. [online] Available at: https://www.w3schools.com/python/numpy_random.asp [Accessed 19 November 2020].
# 2. W3schools.com. 2020. Binomial Distribution. [online] Available at: https://www.w3schools.com/python/numpy_random_binomial.asp [Accessed 19 November 2020].
# 3. Python-ds.com. 2020. Python Binomial Distribution. [online] Available at: http://www.python-ds.com/python-binomial-distribution [Accessed 19 November 2020].
# 4. Zach, V., 2020. How To Use The Binomial Distribution In Python - Statology. [online] Statology. Available at: https://www.statology.org/binomial-distribution-python/ [Accessed 19 November 2020].
# 5. Numpy.org. 2020. Numpy.Unique — Numpy V1.19 Manual. [online] Available at: <https://numpy.org/doc/stable/reference/generated/numpy.unique.html> [Accessed 5 December 2020].
# 6. Stack Overflow. 2020. Convert Two Lists Into A Dictionary. [online] Available at: <https://stackoverflow.com/questions/209840/convert-two-lists-into-a-dictionary> [Accessed 5 December 2020].
# 7. Stack Overflow. 2020. How To Count The Occurrence Of Certain Item In An Ndarray?. [online] Available at: <https://stackoverflow.com/questions/28663856/how-to-count-the-occurrence-of-certain-item-in-an-ndarray> [Accessed 5 December 2020].
# 8. Brazill, K., 2020. Keitho08/Programming_For_Data-Analysis_Assignement1_2020. [online] GitHub. Available at: <https://github.com/Keitho08/Programming_for_Data-Analysis_Assignement1_2020> [Accessed 5 December 2020].
# 9. En.wikipedia.org. 2020. Inverted Bell Curve. [online] Available at: <https://en.wikipedia.org/wiki/Inverted_bell_curve#:~:text=In%20statistics%2C%20an%20inverted%20bell,falling%20off%20on%20both%20sides.> [Accessed 5 December 2020].

# %% [markdown]
# <br>
#
# # 5. Task 4 - Simpson Paradox
# **Task Brief:**
# *November 30th, 2020: Simpson’s paradox is a well-known statistical paradox where a trend evident in a number of groups reverses when the groups are combined into one big data set. Use numpy to create four data sets, each with an x array and a corresponding y array, to demonstrate Simpson’s paradox. You might create your x arrays using numpy.linspace and create the y array for each x using notation like y = a * x + b where you choose the a and b for each x , y pair to demonstrate the paradox. You might see the Wikipedia page for Simpson’s paradox for inspiration.*
# ***

# %% [markdown]
# **Data Set 1**
#
# Simpsons paradox is a phenomenon in probability and statistics, where a trend appears in several groups of data but disappears or reverses when combined or when additional parameters are added. The paradox was first described by Edward H. Simpson in his paper released in 1951, hence the name of the paradox.
# To demonstrate this paradox in this notebook we will simulate data sets that reflect the paradox and also look at some real life case examples.
#
# To to begin illustrating the paradox, lets create a simulated data set below generating random data using the Numpy package. In this data set there will be two groups (X&Y), randomness is introduced but in each case the value for Y will increase by 4 units for every value for X.

# %%
import numpy as np #import numpy as np
import matplotlib.pyplot as plt # import matplotlib.pyplot as plt
plt.style.use("ggplot") # A nicer style to use for plots
plt.rcParams["figure.figsize"] = (18,10) #sets the plots size, bigger than default notebook and better presented.

# %%
np.random.seed(2)
# Step 1 - Lets create our random data
x1 = np.random.normal(20, 2, 100)
# to define x1 we use numpy.random.normal which draws random samples from a normal (Gaussian) distribution. loc(mean)=20,
# standard deviation=2 and size (number of samples) is 100. 
y1 = [4*x + np.random.normal(20,10) for x in x1]
# to define y1 we set the algorithim for y1 to 4 times value for x & numpy random normal value from a normal
# distribution with a mean of 20 and standard deviation of 10, and we want one value for y1 for each value in x1.
a1, b1 = np.polyfit(x1, y1, 1)
# np.polyfit is a special function in numpy that asks numpy to output the best relationship between give values,
# in this case we want the values for a1 and b1 based on positions of x1 and y1 at the degree of the fitting
# polynomial (1).

#same process as above for x2, y2, a2, b2:
x2 = np.random.normal(25, 2, 100) 
y2 = [4*x + np.random.normal(-20, 5) for x in x2]
a2, b2 = np.polyfit(x2, y2, 1)

# Lets have a look at our generated values:
print("a1 is:", a1)
print("b1 is:", b1)
print("a2 is:", a2)
print("b2 is:", b2)
print("x1 position 1 is:", (x1[0]))
print("y1 position 1 is:", (y1[0]))
print("x2 position 1 is:", (x2[0]))
print("y2 position 1 is:", (y2[0]))
# Out:
# a1 is: 4.168896600673914
# b1 is: 17.939522549010853
# a2 is: 4.17398172289471
# b2 is: -23.082886616909015
# x1 position 1 is: 19.16648430518906
# y1 position 1 is: 108.28115212816397
# x2 position 1 is: 22.697994111717705
# y2 position 1 is: 75.14618026991187

# %% [markdown]
# In the above code we first specified the seed to be 2 so we can re-generate the same data on each run of the code, which is useful for reviewing. We set the values for x and y and generate random numbers for both utilising the normal distribution in numpy. We generate 100 values for x and y. Having generated the values for x1 and y1 and x2 and y2, we determine the relationship between the values (coefficients) and we name these coefficient a1, b1, a2 and b2.
#
# From above alogirthim generated for the a1 and b1 polyfits, for each value of y, multiplying the x value by a1 and adding b1 will generate the y position for the x value, these values are based on a degree of the fitting polynomial of 1, i.e. if y is 1. For example: $ y(1) = x * a1 + b1 $.
#
# Having generated our coefficients, we print out the values for a1, a2, b1 and a2 based on this random number generations using seed(2). We also print out for our information the values generated for x1, x2, y1 and y2. Having generated the values for above in next section of code we will generate plots of the data prior to aggregation.
#
# Note the alogorithims to generate values for x's and y's above including means and standard deviations in normal distribution are based on experimentation of values aswell as research online to simulate a dataset that can represent the Simpsons Paradox.

# %%
# Step 2 - Lets have a look at the data before we aggregate it
plt.subplot(1, 2, 1) # Set the position of the subplot
plt.scatter(x1, y1) # scatter plot for x1 y1
plt.scatter(x2, y2) # scatter plot for x2 y2

# Below we set the plot x and y limits so that is cropped to the extent of data in the set
xl, yl = plt.xlim(), plt.ylim() 
plt.xlim(xl)
plt.ylim(yl)
plt.show() # shows the plot

# %% [markdown]
# The above plot shows the values for x1, y1 (red) and x2, y2 (blue). Now lets add our best fit lines in below code using the coefficients we generated for a1, a2, b1 and b2.

# %%
# Step 2 - Lets have a look at the data before we aggregate it
plt.subplot(1, 2, 1) # Set the position of the subplot
plt.scatter(x1, y1) # scatter plot for x1 y1
plt.scatter(x2, y2) # scatter plot for x2 y2
xr1 = np.array([14,26]) 
xr2 = np.array([19,30])
# we can tell from graphs above that data is generated between 14 and 26 for x1, y1 and,
# between 19 to 30 for x2, y2, therefore we can use this range for our best fit line and create
# an array of values between these figures and multiply by our coefficients to generate the line.
plt.plot(xr1, a1*xr1+b1, c='b') # plots a blue line for best fit line
plt.plot(xr2, a2*xr2+b2, c='r') # plots a red line for best fit line
# Below we set the plot x and y limits so that is cropped to the extent of data in the set
xl, yl = plt.xlim(), plt.ylim()
plt.xlim(xl)
plt.ylim(yl)
plt.show()

# %% [markdown]
# Having generated the data sets and the best fit lines above, we can clearly see the line is sloped upwards for both of the plots. However, lets determine now what the best fit line will look like if we combine the data sets. We can do this using the numpy.concatenate function which allows arrays to be added to each other.

# %%
a3, b3 = np.polyfit(np.concatenate((x1, x2)), y1+y2, 1)
# We create two new coefficients for a3 and b3 which will give the values for y when x is 1 
# for the combined data. Lets print these out to the screen and see what these look like. 
print("a3 is:", a3)
print("b3 is:", b3)
# Out:
# a3 is: -0.8490751136570848
# b3 is: 108.92385771846041

# %% [markdown]
# The values for coefficients a3 and b3 are generated above and show a minus figure for coefficient a. Lets plot this best line against the data set and see the outcome.

# %%
plt.subplot(1,2,1) # Set the position of the subplot
plt.scatter(x1, y1, c='black') # black scatter plot x1,y1
plt.scatter(x2, y2, c='black') # black scatter plot x2,y2
# set the limits of the plot:
xl, yl = plt.xlim(), plt.ylim() 
plt.xlim(xl) 
plt.ylim(yl)
x3 = np.array([14,30]) # We know values are between 14, 30 so we use these as x values to generate y for best fit line
plt.plot(x3, a3*x3+b3, 1, c='red') # multiply the array x3 by the coeffs to generate new best fit line
plt.show()

# %% [markdown]
# We can see from the graph output that when the dataset is combined the line slopes downward and the estimate parameter is now negative. In laymans terms when the data was viewed seperatley both represented positive trends but when combined became negative, this is an example of a Simpson Paradox. In the following sections of this notebook we will look at some further examples of Simpsons Paradox and include real life scenarios.

# %% [markdown]
# **Dataset 2**

# %% [markdown]
# In our second data simulation we are going to simulate a medical vacine treatment effectiveness and demonstrate how initially with seperate data we got a particular pattern but once aggregated this changed.
# In this example we will assume that there was an outbreak of a disease at two facilities. A different treatment was given at each facility, one was using **Pfizer** drugs, the other **Moderna** with the aim of the treatment is for at least 60% of the facility to develop immunity of the disease. Following the treatment Pfizer have said that there treatment had a 62% success rate for men and 82% success rate for women. In this instance we are going to assume we are working for the Moderna data analytics team and asked to validate the accuracy of the Pfizer claims and compare to the Moderna success at a seperate facility following a media claim that the Pfizer drugs were more effective than the Moderna drugs.
#
# The code below has been through several iterations to develop this simpsons paradox in order to get a data set that reflected a simpsons paradox. The code is explained in the following sections along with analysis of the output for both drugs. In the code we make a number of assumptions for the uptake of the virus and also the probability of its effectiveness in order to generate a data set to reflect the simpsons paradox.

# %%
import numpy as np # Import numpy as np
#import random as rd
np.random.seed(1) # We set the seed to 1 so we get same results each time, this seed worked well to demonstrate the paradox.

# The following is a list of abbreviations for the variables:
# PMT = Pfizer Male Treated
# PFB = Pfizer Female Treated
# PMB = Pfizer Males Better
# PFB = Pfizer Females Better

# Now lets first generate our Pfizer treatment figures:
PMT = np.random.choice(range(580, 650)) # PMB Assume minimum 89% uptale, 650 males in facility
print('Number of Pfizer Males Treated:', PMT)
# We assume a minium of 89% of people will take the treatment, using numpy random choice we pick a figure
# for the uptake using the minimum 580(89%) to 650 the maximum staff. We then print out to screen.
PFT = np.random.choice(range(75, 110)) # PMB Assume minimum 68% update, 110 females in facility, same as above
print('Number of Pfizer Females Treated:', PFT)
# Once treatment numbers calculated above we can then calculate how many are now immune(treated)
PfizerMalesBetter = np.random.binomial(n=1, p=0.6, size=PMT)
# Using numpy random binomial we set number of outcomes to 1 (0=fail, 1=treated), probability to 0.6(60%effective)
# and size to match the number of males treated (PMT)
PMB = np.count_nonzero(PfizerMalesBetter == 1)
# using np.count_nonzero we can calculate how many of the treated were equal to 1 (successful treatment)
print('Number of Pfizer Males Better:', PMB)
# Same process as above for female:
PfizerFemlesBetter = np.random.binomial(n=1, p=0.88, size=PFT)
PFB = np.count_nonzero(PfizerFemlesBetter == 1)
print('Number of Pfizer Females Better:', PFB)
# Out:
# Number of Pfizer Males Treated: 617
# Number of Pfizer Females Treated: 87
# Number of Pfizer Males Better: 387
# Number of Pfizer Females Better: 72

# %% [markdown]
# Following running of above code we get the following results for the Pfizer patients:
#
# * Number of Pfizer Males Treated: 617
# * Number of Pfizer Females Treated: 87
# * Number of Pfizer Males Better: 387
# * Number of Pfizer Females Better: 72
#
# The key elements of code here were:
#
# * np.random.choice() - allows us to generate a figure for number of patients treated based on assumed min. to max. range
# * np.random.binomial - generates a data set for number of successful patients for male and female based on probability.
# * np.count_nonzero() - allows us to count all values = 1 in the binomial distribution i.e. successfully treated.
#
# Now that we have generated the data for the Pfizer patients we can now apply same methodology to Moderna below:

# %%
import numpy as np
#import random as rd
np.random.seed(1)

# The following is a list of abbreviations for the variables:
# MMT = Moderna Male Treated
# MFB = Moderna Female Treated
# MMB = Moderna Males Better
# MFB = Moderna Females Better

# Lets Generate our Moderna Patients
MMT = np.random.choice(range(135, 150)) # PMB Assume minimum 90% update, 150 males in facility
print('Number of Moderna Males Treated:', MMT)
MFT = np.random.choice(range(200, 250)) # PMB Assume minimum 80% update, 250 females in facility
print('Number of Moderna Females Treated:', MFT)
ModernaMalesBetter = np.random.binomial(n=1, p=0.5, size=MMT)
MMB = np.count_nonzero(ModernaMalesBetter == 1)
print('Number of Moderna Males Better:', MMB)
ModernaFemlesBetter = np.random.binomial(n=1, p=0.8, size=MFT)
MFB = np.count_nonzero(ModernaFemlesBetter == 1)
print('Number of Moderna Females Better:', MFB)
# Out:
# Number of Moderna Males Treated: 140
# Number of Moderna Females Treated: 243
# Number of Moderna Males Better: 74
# Number of Moderna Females Better: 190

# %% [markdown]
# Having generated the numbers for the Pfizer and Moderna patients lets look at a comparison of the male and female treatments success rate as per the Pfizer media claim.

# %%
import numpy as np #import numpy as np 
import pandas as pd #import pandas as pd

data = pd.DataFrame({'Pfizer Better': [PMB, PFB], 'Pfizer Treated': [PMT, PFT], 'Moderna Better': [MMB, MFB], 'Moderna Treated': [MMT, MFT]}, index = ["M", "F"])
# we are creating a table of the data based on values created above using Pandas DataFrame function 
# to create a dictionary of the values for Pfizer and Moderna 
# We set the indexes to 'M' and 'F' to segregate between male and female. 

data['Pfizer Percent'] = data['Pfizer Better'] / data['Pfizer Treated']
# We are setting Pfizer% to be Pfizer Better number divided by Pfizer Treated Number
data['Moderna Percent'] = data['Moderna Better'] / data['Moderna Treated']
# We are setting Moderna % to be Moderna Better number divided by Moderna Treated Number
data #print out data below.
# Out:
#    Pfizer Better  Pfizer Treated  Moderna Better  Moderna Treated  \
# M            387             617              74              140
# F             72              87             190              243
#
#    Pfizer Percent  Moderna Percent
# M        0.627229         0.528571
# F        0.827586         0.781893

# %% [markdown]
# We can see from the results generated from the code above that at face value the Pfizer drug looks more successful for both male and female than the Moderna. Now lets add a third row to the table 'Total' and review the results.

# %%
TotalPfizerTreated= PMT + PFT # adding results of male and female treated Pfizer
TotalModernaTreated= MMT + MFT # adding results of male and female treated Moderna
TotalPfizerBetter= PMB + PFB # adding results of male and female better Pfizer
TotalModernaBetter= MMB + MFB # adding results of male and female better Moderna
#print out data below:
print(TotalPfizerTreated)
print(TotalModernaTreated)
print(TotalPfizerBetter)
print(TotalModernaBetter)
# Out:
# 704
# 383
# 459
# 264

# %%
import numpy as np #import numpy as np 
import pandas as pd #import pandas as pd

data.loc['Total']= data.sum() # We add a new row that will sum rows above
data.loc['Total', 'Pfizer Percent'] = data.loc['Total', 'Pfizer Better'] / data.loc['Total', 'Pfizer Treated']
data.loc['Total', 'Moderna Percent'] = data.loc['Total', 'Moderna Better'] / data.loc['Total', 'Moderna Treated']
# Using data.loc (imported via pandas DataFrame) we can also add a new value for Total percentage to the table
# as specified in the rows of code above. 
data # print out totals table below
# Out:
#        Pfizer Better  Pfizer Treated  Moderna Better  Moderna Treated  \
# M              387.0           617.0            74.0            140.0
# F               72.0            87.0           190.0            243.0
# Total          459.0           704.0           264.0            383.0
#
#        Pfizer Percent  Moderna Percent
# M            0.627229         0.528571
# F            0.827586         0.781893
# Total        0.651989         0.689295

# %%
import matplotlib.pyplot as plt #import matplotlib.pyplot as plt
import seaborn as sns # import seaborn as sns
plt.style.use("ggplot") # A nicer style to use for plots
plt.rcParams["figure.figsize"] = (18,10) #sets the plots size, bigger than default notebook and better presented. 
sns.barplot(data=data[['Pfizer Better', 'Pfizer Treated', 'Moderna Better', 'Moderna Treated']])
# We only want specific columns in the data set in the barplot so we list the columns required only. 
# Lets also look at above table in a plot for the total values under four columns above.

# %% [markdown]
# After generating our data above we identify our Simpsons Paradox as after aggregating our data of males and females treated by Pfizer and Moderna we can see the overall percentage now shows that the Moderna treatment was more successful than Pfizer. And in this scenario gives our Moderna marketing colleagues some excellent material for their media response!
#
# This dataset has used simulated random data to create a Simpsons Paradox based on a real life scenario to try and demonstrate how the Simpsons Paradox could occur in everyday circumstances.

# %% [markdown]
# **Data Set 3**

# %% [markdown]
# For our next data set we are going to again try and relate the Simpsons Paradox to a real world scenario. In this example we are going to compare the hours excercised and effect on probability of getting a disease for two groups, under 50 and over 50. We will then aggregate the data set's and analyse the effect this has.
#
# For the follwoing code we use numpy random integer function to create a sample data set for the number of hours excercised adn the ages between a range of values. Following research online an algorithim was found to determine probability of generating an illness for an under 50 group:
#
# * $p = 12 + 0.5 * ages + -2.1 * hours + σ * 2$
#
# Where
# * p=probability
# * 12, 0.5, -2.1 and 2 are constants
# * ages = a random number from the ages array generated
# * hours = a random value from the hours array generated
# * σ = random number from the sample set standard deviation
#
# Following above methodology we can create a dictionary of the values for the under 50 group using pandas.DataFrame. To simplify the process for adding a regression line in this instance we are going to use any available seaborn function **regplot** to automatically add a regression line to the plot. The seaborn.regplot() draws a scatterplot for two variables x and y and fits the regression model y ~ x and plots the resulting regression line with a 95% confidence interval for the regression.

# %%
import numpy as np # import numpy as np
import matplotlib.pyplot as plt #import matplotlib.pyplot as plt
import seaborn as sns # import seaborn as sns
import pandas as pd # import pandas as pd
plt.style.use("ggplot") # A nicer style to use for plots
plt.rcParams["figure.figsize"] = (10,8) #sets the plots size

n_samples = 100 # our number of samples
np.random.seed(3) # we want to use seed so we can review same results each time
ages = np.random.randint(20, 50, n_samples) # random integer between 20-50, size = n_samples(100)
hours = np.random.randint(1, 5, n_samples) + np.random.randn(n_samples) # random integer between 1-5, size = n_samples(100)
p = 12 + 0.5 * ages + -2.1 * hours + np.random.randn(n_samples) *  2 # algorithim for probability of disease/illness
# random.randn returns samples from the “standard normal” distribution
under_50 = pd.DataFrame({'age': ages, 'Hours Exercised': hours, 'probability': p}) # creates a dictionary for dataset

under_50plot = sns.regplot(x='Hours Exercised', y='probability', data=under_50, scatter_kws={"color": "b"}, line_kws={"color": "red"}) 
# plots a regplot with given parameters for dataset, scatter_kws and line_kws specifies colors for scatter points and line
plt.title("Under 50 - Probability of Getting Illness vs. Hours Excercised") # adds plot title
# Out:
# Text(0.5, 1.0, 'Under 50 - Probability of Getting Illness vs. Hours Excercised')

# %% [markdown]
# We can see from our output plot regression line that their is a negative correlation between hours excercised and probabibility of getting an illness. Which makes sense for younger age groups. Now lets change the constant values in our probability algorithim and apply the same code to the over 50s group below.

# %%
import numpy as np # import numpy as np
import matplotlib.pyplot as plt #import matplotlib.pyplot as plt
import seaborn as sns # import seaborn as sns
import pandas as pd # import pandas as pd
plt.style.use("ggplot") # A nicer style to use for plots
plt.rcParams["figure.figsize"] = (10,8) #sets the plots size

n_samples = 100 # our number of samples
np.random.seed(4) # we want to use seed so we can review same results each time
ages1 = np.random.randint(50, 85, n_samples) # random integer between 50-85, size = n_samples(100)
hours1 = np.random.randint(3, 8, n_samples) + np.random.randn(n_samples) * 0.5 # random integer between 1-5, size = n_samples(100)
p = 40 + 0.32 * ages + -3.2 * hours + np.random.randn(n_samples) # algorithim for probability of disease/illness
# random.randn returns samples from the “standard normal” distribution
over_50 = pd.DataFrame({'age': ages1, 'Hours Exercised': hours1, 'probability': p}) # creates a dictionary for dataset

over_50plot = sns.regplot(x='Hours Exercised', y='probability', data=over_50, scatter_kws={"color": "g"}, line_kws={"color": "red"}) 
# plots a regplot with given parameters for dataset, scatter_kws and line_kws specifies colors for scatter points and line
plt.title("Over 50 - Probability of Getting Illness vs. Hours Excercised") # adds plot title
# Out:
# Text(0.5, 1.0, 'Over 50 - Probability of Getting Illness vs. Hours Excercised')

# %% [markdown]
# We can see a slight positive correlation between the relationship hours excercised and proabability in the over 50s group due to the change in our algorithim to reflect that contributing factor of age. What can be determined from these results is that although several hours of excercise can be done due to the age of the person they still have a higher probability of getting an illness even if the excercise hours are greater (3 to 8).
#
# Finally lets combine the two data sets together using pd.concat to add the two dictionaries for under and over 50 and plot a final regression plot.

# %%
combinedfitness = pd.concat([under_50, over_50], axis = 0) # using pd.concat we can combine our two dictionaries for the data sets
combined_plot = sns.regplot(x='Hours Exercised', y='probability', data=combinedfitness, scatter_kws={"color": "black"}, line_kws={"color": "red"}) 
# plots a regplot with given parameters for dataset, scatter_kws and line_kws specifies colors for scatter points and line
plt.title("Over 50 - Probability of Getting Illness vs. Hours Excercised") # adds plot title
# Out:
# Text(0.5, 1.0, 'Over 50 - Probability of Getting Illness vs. Hours Excercised')

# %% [markdown]
# We can show that when aggregated the hours excercised between the under and over 50 group it leads to a coorelation reversal in the under 50's and also a higher probability for the over 50s! This is our Simpsons Paradox as aggregating our data has reversed our pattern in the under 50s. They key variable age, which was looked at independently in our previous plots, is such a significance factor in the probability that this plot is very in-accurate for a larger percentage of the population.

# %% [markdown]
# **Data Set 4**
#
# In our final example for Simpsons Paradox we are going to simulate an example of restaurant reviews and show how a paradox is created when aggregating the data set.
#
# In this example we are going to simulate restaurant reviews for two restaurant chains McDonalds and Supermacs. The reviewers will be either Irish our American. We assume for purpose of this data set the following:
#
# * All reviews counted are positive
# * Statistically Irish are 33% likley to leave a good review for Burker King
# * Statistically Irish are 50% likley to leave a good review for McDonalds
# * Statistically Americans are 80% likley to leave a good review for Burker King
# * Statistically Americans are 90% likley to leave a good review for McDonalds
#
# We will generate some random data based on these assumptions below. Note the below code is a concise version following a number of tests of the data values to produce a Simpsons Paradox.

# %%
import numpy as np # import numpy as np
import matplotlib.pyplot as plt #import matplotlib.pyplot as plt
import pandas as pd # import pandas as pd

np.random.seed(1) # We set the seed to 1 for reviewing of same results

# Lets first create our total number of visitors for each index
IrishBK = 150 # Irish Burger King Visitors
IrishMc = 360 # Irish McDonald Visitors 
AmericanBK = 250 # American Burger King Visitors
AmericanMc = 40 # American McDonal Visitors

# Lets then randomly determine number of reviewers for each restaurant based on probabilities:
IrishBKrevs = np.random.binomial(n=1, p=0.33, size=IrishBK) # Irish Burger King how many left(1) and did not leave(0)
IrishMcrevs = np.random.binomial(n=1, p=0.50, size=IrishMc) # Irish McDonald how many left(1) and did not leave(0) 
AmericanBKrevs = np.random.binomial(n=1, p=0.8, size=AmericanBK) # American Burger how many left(1) and did not leave(0)
AmericanMcrevs = np.random.binomial(n=1, p=0.9, size=AmericanMc) # American McDonald how many left(1) and did not leave(0)

# Lets only count reviews left:
IrishBKrevsNo = np.count_nonzero(IrishBKrevs == 1) # Irish Burger King reviewers number left
IrishMcrevsNo = np.count_nonzero(IrishMcrevs == 1) # Irish McDonald reviewers number left
AmericanBKrevsNo = np.count_nonzero(AmericanBKrevs == 1) # American Burger reviewers number left
AmericanMcrevsNo = np.count_nonzero(AmericanMcrevs == 1) # American McDonald reviewers number left

data = pd.DataFrame({"Burger King Visitors": [IrishBK, AmericanBK], "McDonalds Visitors": [IrishMc, AmericanMc], "Reviewers Burger King": [IrishBKrevsNo, AmericanBKrevsNo], "Reviewers McDonalds": [IrishMcrevsNo, AmericanMcrevsNo]}, index = ["Irish", "American"])
data["Burger King Percent"] = data["Reviewers Burger King"] / data["Burger King Visitors"]
data["McDonalds Percent"] = data["Reviewers McDonalds"] / data["McDonalds Visitors"]
data
# Out:
#           Burger King Visitors  McDonalds Visitors  Reviewers Burger King  \
# Irish                      150                 360                     53
# American                   250                  40                    205
#
#           Reviewers McDonalds  Burger King Percent  McDonalds Percent
# Irish                     192             0.353333           0.533333
# American                   37             0.820000           0.925000

# %% [markdown]
# Applying the code we get the output table of the results for number of positive reviews in each restaurant. We can see that both Irish and American have left more positive reviews for McDonalds.
#
# The key elements of code here were:
# * np.random.binomial - generates a data set for number of reviewers based on probability from total number of visitors.
# * np.count_nonzero() - allows us to count all values = 1 in the binomial distribution i.e. good reviews
# * pd.Dataframe - pandas function allows us to input and read the data in a dictionary.
#
# Now lets combine the two data sets below and review results.

# %%
data.loc['combined']= data.sum() # We add a new row that will sum rows above
data.loc['combined', 'Burger King Percent'] = data.loc['combined', 'Reviewers Burger King'] / data.loc['combined', 'Burger King Visitors']
data.loc['combined', 'McDonalds Percent'] = data.loc['combined', 'Reviewers McDonalds'] / data.loc['combined', 'McDonalds Visitors']
# Using data.loc (imported via pandas DataFrame) we can also add a new value for Total percentage to the table
# as specified in the rows of code above. 
data # print out totals table below
# Out:
#           Burger King Visitors  McDonalds Visitors  Reviewers Burger King  \
# Irish                    150.0               360.0                   53.0
# American                 250.0                40.0                  205.0
# combined                 400.0               400.0                  258.0
#
#           Reviewers McDonalds  Burger King Percent  McDonalds Percent
# Irish                   192.0             0.353333           0.533333
# American                 37.0             0.820000           0.925000
# combined                229.0             0.645000           0.572500

# %% [markdown]
# After combining the results we end up with a Simpsons Paradox, as following aggregation of the data the combined reviews shows that overall Burger King has received a higher number of positive reviews than McDonalds, in comparison to reviewing these seperately by nationality above.

# %% [markdown]
# ***
# **Python Packages used for Task 4:**
# * Numpy Random Package
# * Matplolib.pyplot
# * Seaborn
# * Pandas
# ***

# %% [markdown]
# **References**
#
# 1. Brazill, K., 2020. Keitho08/Programming_For_Data-Analysis_Assignement1_2020. [online] GitHub. Available at: <https://github.com/Keitho08/Programming_for_Data-Analysis_Assignement1_2020> [Accessed 5 December 2020].
# 2. McLoughlin, I., 2020. Ianmcloughlin/Jupyter-Teaching-Notebooks. [online] GitHub. Available at: <https://github.com/ianmcloughlin/jupyter-teaching-notebooks/blob/master/fitting-lines.ipynb> [Accessed 7 December 2020].
# 3. GitHub. 2020. Willkoehrsen/Data-Analysis. [online] Available at: <https://github.com/WillKoehrsen/Data-Analysis/blob/master/statistics/Simpson's%20Paradox.ipynb> [Accessed 7 December 2020].
# 4. GitHub. 2020. Camdavidsonpilon/Simpsons-Paradox. [online] Available at: <https://github.com/CamDavidsonPilon/simpsons-paradox/blob/master/detect_paradox.py> [Accessed 7 December 2020].
# 5. Medium. 2020. Solving Simpson’S Paradox. [online] Available at: <https://towardsdatascience.com/solving-simpsons-paradox-e85433c68d03> [Accessed 7 December 2020].
# 6. Medium. 2020. Simpson’S Paradox: How To Prove Opposite Arguments With The Same Data. [online] Available at: <https://towardsdatascience.com/simpsons-paradox-how-to-prove-two-opposite-arguments-using-one-dataset-1c9c917f5ff9#:~:text=Simpson's%20Paradox%20occurs%20when%20trends,when%20the%20data%20are%20aggregated.&text=Since%20men%20tend%20to%20approve,combined%20and%20hence%20a%20paradox.> [Accessed 7 December 2020].
# 7. Medium. 2020. What Is Simpson’S Paradox?. [online] Available at: <https://towardsdatascience.com/what-is-simpsons-paradox-4a53cd4e9ee2> [Accessed 7 December 2020].
# 8. Pearl, J., 2020. Understanding Simpson’S Paradox. [online] Ftp.cs.ucla.edu. Available at: <https://ftp.cs.ucla.edu/pub/stat_ser/r414.pdf> [Accessed 7 December 2020].
# 9. paulvanderlaken.com. 2020. Simpson’S Paradox: Two HR Examples With R Code.. [online] Available at: <https://paulvanderlaken.com/2017/09/27/simpsons-paradox-two-hr-examples-with-r-code/> [Accessed 7 December 2020].
# 10. Pandas.pydata.org. 2020. Pandas.Dataframe.Loc — Pandas 1.1.4 Documentation. [online] Available at: <https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html> [Accessed 7 December 2020].
# 11. Seaborn.pydata.org. 2020. Seaborn.Regplot — Seaborn 0.11.0 Documentation. [online] Available at: <https://seaborn.pydata.org/generated/seaborn.regplot.html> [Accessed 7 December 2020].
# 12. Docs.scipy.org. 2020. Numpy.Random.Randint — Numpy V1.15 Manual. [online] Available at: <https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.randint.html> [Accessed 7 December 2020].
# 13. Stack Overflow. 2020. Different Colors For Points And Line In Seaborn Regplot. [online] Available at: <https://stackoverflow.com/questions/48145924/different-colors-for-points-and-line-in-seaborn-regplot/48146987> [Accessed 7 December 2020].
# 14. Docs.scipy.org. 2020. Numpy.Random.Randn — Numpy V1.15 Manual. [online] Available at: <https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.random.randn.html> [Accessed 7 December 2020].
# 15. Seaborn.pydata.org. 2020. Visualizing Regression Models — Seaborn 0.11.0 Documentation. [online] Available at: <https://seaborn.pydata.org/tutorial/regression.html> [Accessed 7 December 2020].
# 16. Numpy.org. 2020. Numpy.Concatenate — Numpy V1.19 Manual. [online] Available at: <https://numpy.org/doc/stable/reference/generated/numpy.concatenate.html> [Accessed 7 December 2020].
# 17. Numpy.org. 2020. Numpy.Polyfit — Numpy V1.19 Manual. [online] Available at: <https://numpy.org/doc/stable/reference/generated/numpy.polyfit.html> [Accessed 7 December 2020].
# ***

# %% [markdown]
# <br>
#
# # 6. Conclusion
